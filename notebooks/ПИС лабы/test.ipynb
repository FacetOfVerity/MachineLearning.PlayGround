# %%
from pandas import read_csv
dataset = read_csv("adult.data.csv")

#print(dataset)

# %%
countries = dataset['native-country']#все страны

from collections import OrderedDict

uniqueCountries = OrderedDict( (x,1) for x in countries.values ).keys()
testuniqueCountries = uniqueCountries[0:3]

amount = len(uniqueCountries)

frequencies = dataset.groupby(by=['native-country']).size().reset_index(name='counts')
print(scores)
# Out:
#                 native-country  counts
# 0                            ?     583
# 1                     Cambodia      19
# 2                       Canada     121
# 3                        China      75
# 4                     Columbia      59
# 5                         Cuba      95
# 6           Dominican-Republic      70
# 7                      Ecuador      28
# 8                  El-Salvador     106
# 9                      England      90
# 10                      France      29
# 11                     Germany     137
# 12                      Greece      29
# 13                   Guatemala      64
# 14                       Haiti      44
# 15          Holand-Netherlands       1
# 16                    Honduras      13
# 17                        Hong      20
# 18                     Hungary      13
# 19                       India     100
# 20                        Iran      43
# 21                     Ireland      24
# 22                       Italy      73
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,15))
cut = frequencies[1:21]
plt.bar(cut['native-country'].values, cut['counts'].values)
plt.ylabel("Frequency")
plt.show()

# %%
plt.plot('native-country', 'counts', data=cut)
